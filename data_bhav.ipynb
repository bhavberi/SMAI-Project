# %%
from music21 import *
# from music21.midi.realtime import StreamPlayer

# %% [markdown]
# ## Utils

# %%
music_file_path = "Music/{}.mid"

# %%
def analyze_midi_score(midi_score):
    try:
        # Iterate through MIDI tracks and events
        for part_idx, part in enumerate(midi_score.parts):
            print(f"Track {part_idx + 1}:")

            for event in part.flat.notesAndRests:
                if event.isNote:
                    # Extract note information
                    note = event.pitch
                    duration = event.duration
                    print(f"Note: Pitch={note}, Duration={duration.quarterLength}")

                elif event.isStream and 'Instrument' in event.classes:
                    # Handle instrument changes
                    instrument = event.instrumentName
                    print(f"Instrument Change: {instrument}")

    except Exception as e:
        print(f"Error: {e}")

# %%
def see_midi_score(midi_score):
    try:
        # Export the score to MusicXML format
        musicxml_path = 'output_score.xml'
        midi_score.write('musicxml', musicxml_path)

        # Print or further process the MusicXML file
        print(f"Score exported to {musicxml_path}")

        midi_xml = converter.parse(musicxml_path)
        # midi_xml.show('text')
        midi_xml.show()

    except Exception as e:
        print(f"Error: {e}")

# %% [markdown]
# ## Main Code

# %%
mond_3 = music_file_path.format('mond_3')

# %%
# Load the MIDI file and show the summary
midi_stream = midi.MidiFile()
midi_stream.open(mond_3)
midi_stream.read()
midi_stream.close()

midi_score = converter.parse(mond_3)

# midi_stream.tracks[0].events

# %%
analyze_midi_score(midi_score)
# Out:
# Track 1:
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C3, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C3, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=F3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=F#3, Duration=0.25
# Note: Pitch=A3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=B-4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=B-4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#3, Duration=3.0
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#6, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=C#6, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=C#6, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=B-3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=B-3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=B-4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=B-4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=B-4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=B-4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=B-5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=B-5, Duration=0.25
# Note: Pitch=C#6, Duration=0.25
# Note: Pitch=B-5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B-5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B-4, Duration=0.25
# Note: Pitch=B4, Duration=0.5
# Note: Pitch=E-5, Duration=2.0
# Note: Pitch=B4, Duration=0.75
# Note: Pitch=G#4, Duration=1.0
# Note: Pitch=G4, Duration=1.5
# Note: Pitch=G4, Duration=0.5
# Note: Pitch=E-5, Duration=0.75
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=B-4, Duration=1.0
# Note: Pitch=G#4, Duration=1.5
# Note: Pitch=G#4, Duration=0.5
# Note: Pitch=E-5, Duration=0.75
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=B4, Duration=1.0
# Note: Pitch=B-4, Duration=1.5
# Note: Pitch=B-4, Duration=0.5
# Note: Pitch=E-5, Duration=0.75
# Note: Pitch=B-4, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=B-4, Duration=1.0
# Note: Pitch=B-5, Duration=0.25
# Note: Pitch=G4, Duration=1.0
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=B5, Duration=0.25
# Note: Pitch=C#6, Duration=0.25
# Note: Pitch=B5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=B5, Duration=0.25
# Note: Pitch=C#6, Duration=0.25
# Note: Pitch=B5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=B5, Duration=0.25
# Note: Pitch=C#6, Duration=0.25
# Note: Pitch=B5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=B5, Duration=0.25
# Note: Pitch=C#6, Duration=0.25
# Note: Pitch=D6, Duration=0.25
# Note: Pitch=E6, Duration=0.25
# Note: Pitch=E-6, Duration=0.25
# Note: Pitch=E6, Duration=0.25
# Note: Pitch=E-6, Duration=0.25
# Note: Pitch=E6, Duration=0.25
# Note: Pitch=C#6, Duration=0.25
# Note: Pitch=B5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=G#5, Duration=2.0
# Note: Pitch=G#5, Duration=0.5
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=B5, Duration=0.25
# Note: Pitch=C#6, Duration=0.25
# Note: Pitch=D6, Duration=0.25
# Note: Pitch=E-6, Duration=0.25
# Note: Pitch=B4, Duration=0.75
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G4, Duration=1.0
# Note: Pitch=E-5, Duration=3.0
# Note: Pitch=B5, Duration=0.75
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=G5, Duration=1.0
# Note: Pitch=E-6, Duration=1.75
# Note: Pitch=E-6, Duration=1.75
# Note: Pitch=E-6, Duration=1.75
# Note: Pitch=E-6, Duration=2.0
# Note: Pitch=B3, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=B3, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=B3, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=B3, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C3, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C3, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=F3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=F#3, Duration=0.25
# Note: Pitch=A3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=B-4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=B-4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#3, Duration=3.0
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#6, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=C#6, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=C#6, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=B-3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=B-3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=B-4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=B-4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=B-4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=B-4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=B-5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=B-5, Duration=0.25
# Note: Pitch=C#6, Duration=0.25
# Note: Pitch=B-5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B-5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B-4, Duration=0.25
# Note: Pitch=B4, Duration=0.5
# Note: Pitch=E-5, Duration=2.0
# Note: Pitch=B4, Duration=0.75
# Note: Pitch=G#4, Duration=1.0
# Note: Pitch=G4, Duration=1.5
# Note: Pitch=G4, Duration=0.5
# Note: Pitch=E-5, Duration=0.75
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=B-4, Duration=1.0
# Note: Pitch=G#4, Duration=1.5
# Note: Pitch=G#4, Duration=0.5
# Note: Pitch=E-5, Duration=0.75
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=B4, Duration=1.0
# Note: Pitch=B-4, Duration=1.5
# Note: Pitch=B-4, Duration=0.5
# Note: Pitch=E-5, Duration=0.75
# Note: Pitch=B-4, Duration=0.25
# Note: Pitch=B4, Duration=0.5
# Note: Pitch=B-4, Duration=1.0
# Note: Pitch=B-5, Duration=0.25
# Note: Pitch=G4, Duration=1.0
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=B5, Duration=0.25
# Note: Pitch=C#6, Duration=0.25
# Note: Pitch=B5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=B5, Duration=0.25
# Note: Pitch=C#6, Duration=0.25
# Note: Pitch=B5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=B5, Duration=0.25
# Note: Pitch=C#6, Duration=0.25
# Note: Pitch=B5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=B5, Duration=0.25
# Note: Pitch=C#6, Duration=0.25
# Note: Pitch=D6, Duration=0.25
# Note: Pitch=E6, Duration=0.25
# Note: Pitch=E-6, Duration=0.25
# Note: Pitch=E6, Duration=0.25
# Note: Pitch=E-6, Duration=0.25
# Note: Pitch=E6, Duration=0.25
# Note: Pitch=C#6, Duration=0.25
# Note: Pitch=B5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=G#5, Duration=2.0
# Note: Pitch=G#5, Duration=0.5
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=B5, Duration=0.25
# Note: Pitch=C#6, Duration=0.25
# Note: Pitch=D6, Duration=0.25
# Note: Pitch=E-6, Duration=0.25
# Note: Pitch=B4, Duration=0.75
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G4, Duration=1.0
# Note: Pitch=E-5, Duration=3.0
# Note: Pitch=B5, Duration=0.75
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=G5, Duration=1.0
# Note: Pitch=E-6, Duration=1.75
# Note: Pitch=E-6, Duration=1.75
# Note: Pitch=E-6, Duration=1.75
# Note: Pitch=E-6, Duration=2.0
# Note: Pitch=B3, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=B3, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=B3, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=B3, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=F3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=F3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=F#3, Duration=0.25
# Note: Pitch=A3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=B3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=B5, Duration=0.25
# Note: Pitch=C#5, Duration=2.0
# Note: Pitch=A4, Duration=0.75
# Note: Pitch=F#4, Duration=1.0
# Note: Pitch=F4, Duration=1.5
# Note: Pitch=F4, Duration=0.5
# Note: Pitch=C#5, Duration=0.75
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#4, Duration=1.0
# Note: Pitch=F#4, Duration=1.5
# Note: Pitch=F#4, Duration=0.5
# Note: Pitch=C#5, Duration=0.75
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=A4, Duration=1.0
# Note: Pitch=G#4, Duration=1.5
# Note: Pitch=G#4, Duration=0.5
# Note: Pitch=C#5, Duration=0.75
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#4, Duration=2.0
# Note: Pitch=A4, Duration=0.5
# Note: Pitch=G#4, Duration=0.5
# Note: Pitch=F#4, Duration=1.0
# Note: Pitch=G#4, Duration=0.5
# Note: Pitch=F#4, Duration=0.5
# Note: Pitch=E4, Duration=1.0
# Note: Pitch=F#4, Duration=0.5
# Note: Pitch=E4, Duration=0.5
# Note: Pitch=E-4, Duration=1.0
# Note: Pitch=E4, Duration=0.5
# Note: Pitch=E-4, Duration=0.5
# Note: Pitch=C#4, Duration=1.0
# Note: Pitch=E-4, Duration=0.5
# Note: Pitch=C#4, Duration=0.5
# Note: Pitch=E-4, Duration=0.75
# Note: Pitch=G#5, Duration=1.5
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=C#5, Duration=0.5
# Note: Pitch=C5, Duration=0.5
# Note: Pitch=C5, Duration=0.5
# Note: Pitch=C#5, Duration=0.5
# Note: Pitch=C#5, Duration=0.5
# Note: Pitch=E-5, Duration=0.5
# Note: Pitch=E-5, Duration=0.5
# Note: Pitch=C#5, Duration=0.5
# Note: Pitch=C#5, Duration=0.5
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C3, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C3, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=F3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=F#3, Duration=0.25
# Note: Pitch=A3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=B-4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=B-4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#3, Duration=3.0
# Note: Pitch=G#4, Duration=2.0
# Note: Pitch=E4, Duration=0.75
# Note: Pitch=C#4, Duration=1.0
# Note: Pitch=C4, Duration=1.5
# Note: Pitch=C4, Duration=0.5
# Note: Pitch=G#4, Duration=0.75
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=E-4, Duration=1.0
# Note: Pitch=C#4, Duration=1.5
# Note: Pitch=C#4, Duration=0.5
# Note: Pitch=G#4, Duration=0.75
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=1.0
# Note: Pitch=E-4, Duration=1.5
# Note: Pitch=E-4, Duration=0.5
# Note: Pitch=G#4, Duration=0.75
# Note: Pitch=E-4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=E-4, Duration=1.0
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=C4, Duration=1.0
# Note: Pitch=C5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=B5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=C#5, Duration=2.0
# Note: Pitch=E-5, Duration=0.25
# Note: Pitch=C#5, Duration=0.5
# Note: Pitch=A3, Duration=0.25
# Note: Pitch=B3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=D4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=D4, Duration=0.25
# Note: Pitch=A3, Duration=0.25
# Note: Pitch=B3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=D4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=D4, Duration=0.25
# Note: Pitch=A3, Duration=0.25
# Note: Pitch=B3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=D4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=D4, Duration=0.25
# Note: Pitch=A3, Duration=0.25
# Note: Pitch=B3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=D4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=G4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=B4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=D5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=G5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=E4, Duration=0.75
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=C4, Duration=1.0
# Note: Pitch=G#4, Duration=3.0
# Note: Pitch=E5, Duration=0.75
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=C5, Duration=1.0
# Note: Pitch=G#5, Duration=1.75
# Note: Pitch=G#5, Duration=1.75
# Note: Pitch=G#5, Duration=1.75
# Note: Pitch=G#5, Duration=2.0
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=F#3, Duration=0.25
# Note: Pitch=A3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F#3, Duration=0.25
# Note: Pitch=A3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=A3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=A4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=F#5, Duration=0.25
# Note: Pitch=A5, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=G#5, Duration=0.25
# Note: Pitch=C#4, Duration=1.5
# Note: Pitch=C#5, Duration=1.0
# Note: Pitch=C#6, Duration=3.0
# Note: Pitch=A3, Duration=1.5
# Note: Pitch=A4, Duration=1.0
# Note: Pitch=A4, Duration=3.75
# Note: Pitch=C5, Duration=3.5
# Note: Pitch=E-5, Duration=3.25
# Note: Pitch=A5, Duration=3.0
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# ...
# Note: Pitch=D3, Duration=0.25
# Note: Pitch=F#2, Duration=0.25
# Note: Pitch=D3, Duration=0.25
# Note: Pitch=A2, Duration=0.25
# Note: Pitch=D3, Duration=0.25
# Note: Pitch=F#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=E2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=C4, Duration=0.25
# Note: Pitch=F#4, Duration=0.25
# Note: Pitch=F#2, Duration=0.25
# Note: Pitch=D3, Duration=0.25
# Note: Pitch=A2, Duration=0.25
# Note: Pitch=D3, Duration=0.25
# Note: Pitch=F#2, Duration=0.25
# Note: Pitch=D3, Duration=0.25
# Note: Pitch=A2, Duration=0.25
# Note: Pitch=D3, Duration=0.25
# Note: Pitch=G2, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=B-2, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G2, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=B-2, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#1, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=G2, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=G2, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=G2, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=F#2, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=F#3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=F#3, Duration=0.25
# Note: Pitch=E3, Duration=0.5
# Note: Pitch=F#2, Duration=0.5
# Note: Pitch=G#2, Duration=0.5
# Note: Pitch=G#2, Duration=0.5
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=B1, Duration=0.25
# Note: Pitch=B2, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=B2, Duration=0.25
# Note: Pitch=B1, Duration=0.25
# Note: Pitch=B2, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=B2, Duration=0.25
# Note: Pitch=B1, Duration=0.25
# Note: Pitch=B2, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=B2, Duration=0.25
# Note: Pitch=B1, Duration=0.25
# Note: Pitch=B2, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=B2, Duration=0.25
# Note: Pitch=F#2, Duration=0.25
# Note: Pitch=A1, Duration=0.25
# Note: Pitch=F#2, Duration=0.25
# Note: Pitch=A1, Duration=0.25
# Note: Pitch=F#2, Duration=0.25
# Note: Pitch=A1, Duration=0.25
# Note: Pitch=F#2, Duration=0.25
# Note: Pitch=A1, Duration=0.25
# Note: Pitch=F#2, Duration=0.25
# Note: Pitch=A1, Duration=0.25
# Note: Pitch=F#2, Duration=0.25
# Note: Pitch=A1, Duration=0.25
# Note: Pitch=F#2, Duration=0.25
# Note: Pitch=F#2, Duration=0.25
# Note: Pitch=G#1, Duration=0.25
# Note: Pitch=E2, Duration=0.25
# Note: Pitch=G#1, Duration=0.25
# Note: Pitch=E2, Duration=0.25
# Note: Pitch=G#1, Duration=0.25
# Note: Pitch=E2, Duration=0.25
# Note: Pitch=G#1, Duration=0.25
# Note: Pitch=E2, Duration=0.25
# Note: Pitch=G#1, Duration=0.25
# Note: Pitch=E2, Duration=0.25
# Note: Pitch=G#1, Duration=0.25
# Note: Pitch=E2, Duration=0.25
# Note: Pitch=G#1, Duration=0.25
# Note: Pitch=E2, Duration=0.25
# Note: Pitch=E2, Duration=0.25
# Note: Pitch=G1, Duration=1.5
# Note: Pitch=G2, Duration=1.5
# Note: Pitch=G3, Duration=0.5
# Note: Pitch=F#1, Duration=1.5
# Note: Pitch=F#2, Duration=1.5
# Note: Pitch=F#3, Duration=0.5
# Note: Pitch=C#3, Duration=0.5
# Note: Pitch=G#3, Duration=2.0
# Note: Pitch=E3, Duration=0.75
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#3, Duration=1.0
# Note: Pitch=C3, Duration=1.5
# Note: Pitch=C3, Duration=0.5
# Note: Pitch=G#3, Duration=0.75
# Note: Pitch=C3, Duration=0.25
# Note: Pitch=E-3, Duration=1.0
# Note: Pitch=C#3, Duration=1.5
# Note: Pitch=C#3, Duration=0.5
# Note: Pitch=G#3, Duration=0.75
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=E3, Duration=1.0
# Note: Pitch=E-3, Duration=1.5
# Note: Pitch=E-3, Duration=0.5
# Note: Pitch=G#3, Duration=0.75
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=F#3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=F#3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=F#3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=F#3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=F#3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=F#3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=F#3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=F#3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=B2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=B2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=B2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=B2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=A2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=A2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=A2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=A2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=F2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=F2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=F2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=F2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=C#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E-3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=E5, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=C#5, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=G#4, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E4, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=C#4, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#3, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E3, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E2, Duration=0.25
# Note: Pitch=C#3, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=E2, Duration=0.25
# Note: Pitch=G#2, Duration=0.25
# Note: Pitch=C#2, Duration=1.0
# /home/bhavb/.local/lib/python3.10/site-packages/music21/stream/base.py:3694: Music21DeprecationWarning: .flat is deprecated.  Call .flatten() instead
#   return self.iter().getElementsByClass(classFilterList)

# %%
print("Number of Parts:", len(midi_score.parts))
for part in midi_score.parts:
    print("Part:", part.partName)
    for element in part.notes:
        print(element)
# Out:
# Number of Parts: 2
# Part: Piano right
# Part: Piano left

# %%
midi_score.show('midi')

# %%
# midi_score.show()
see_midi_score(midi_score)

# %%
chords = midi_score.chordify()

for m in chords.getElementsByClass('Measure'):
    k = m.analyze('key')
    print(m.number, k)
# Out:
# 1 c# minor
# 2 c# minor
# 3 A- major
# 4 A- major
# 5 C# major
# 6 C# major
# 7 f# minor
# 8 A major
# 9 A- major
# 10 c# minor
# 11 A- major
# 12 c# minor
# 13 C# major
# 14 C# major
# 15 c# minor
# 16 c# minor
# 17 A major
# 18 A major
# 19 E- major
# 20 E- major
# 21 g# minor
# 22 E- major
# 23 g# minor
# 24 E- major
# 25 g# minor
# 26 E- major
# 27 g# minor
# 28 E- major
# 29 A- major
# 30 g# minor
# 31 f# minor
# 32 C# major
# 33 A major
# 34 A major
# 35 A major
# 36 g# minor
# 37 A major
# 38 A major
# 39 A major
# 40 A major
# 41 E major
# 42 G major
# 43 g# minor
# 44 A- major
# 45 g# minor
# 46 A- major
# 47 g# minor
# 48 g# minor
# 49 g# minor
# 50 c# minor
# 51 g# minor
# 52 c# minor
# 53 g# minor
# 54 g# minor
# 55 c# minor
# 56 g# minor
# 57 g# minor
# 58 E- major
# 59 g# minor
# 60 E- major
# 61 A- major
# 62 A- major
# 63 g# minor
# 64 B major
# 65 c# minor
# 66 c# minor
# 67 A- major
# 68 A- major
# 69 C# major
# 70 C# major
# 71 f# minor
# 72 A major
# 73 A- major
# 74 c# minor
# 75 A- major
# 76 c# minor
# 77 C# major
# 78 C# major
# 79 c# minor
# 80 c# minor
# 81 A major
# 82 A major
# 83 E- major
# 84 E- major
# 85 g# minor
# 86 E- major
# 87 g# minor
# 88 E- major
# 89 g# minor
# 90 E- major
# 91 g# minor
# 92 E- major
# 93 A- major
# 94 g# minor
# 95 f# minor
# 96 C# major
# 97 A major
# 98 A major
# 99 A major
# 100 g# minor
# 101 A major
# 102 A major
# 103 A major
# 104 A major
# 105 E major
# 106 G major
# 107 g# minor
# 108 A- major
# 109 g# minor
# 110 A- major
# 111 g# minor
# 112 g# minor
# 113 g# minor
# 114 c# minor
# 115 g# minor
# 116 c# minor
# 117 g# minor
# 118 g# minor
# 119 c# minor
# 120 g# minor
# 121 g# minor
# 122 E- major
# 123 g# minor
# 124 E- major
# 125 A- major
# 126 A- major
# 127 g# minor
# 128 B major
# 129 C# major
# 130 C# major
# 131 C# major
# 132 C# major
# 133 f# minor
# 134 C# major
# 135 f# minor
# 136 C# major
# 137 f# minor
# 138 C# major
# 139 f# minor
# 140 C# major
# 141 f# minor
# 142 D major
# 143 G major
# 144 D major
# 145 G major
# 146 C# major
# 147 D major
# 148 A- major
# 149 A major
# 150 B major
# 151 C# major
# 152 E major
# 153 c# minor
# 154 c# minor
# 155 C# major
# 156 E major
# 157 c# minor
# 158 c# minor
# 159 c# minor
# 160 c# minor
# 161 c# minor
# 162 c# minor
# 163 c# minor
# 164 f# minor
# 165 A- major
# 166 c# minor
# 167 c# minor
# 168 A- major
# 169 A- major
# 170 C# major
# 171 C# major
# 172 f# minor
# 173 A major
# 174 A- major
# 175 c# minor
# 176 A- major
# 177 c# minor
# 178 C# major
# 179 C# major
# 180 c# minor
# 181 A- major
# 182 c# minor
# 183 A- major
# 184 c# minor
# 185 A- major
# 186 c# minor
# 187 A- major
# 188 C# major
# 189 c# minor
# 190 b minor
# 191 F# major
# 192 D major
# 193 D major
# 194 D major
# 195 c# minor
# 196 D major
# 197 D major
# 198 D major
# 199 A major
# 200 C major
# 201 c# minor
# 202 C# major
# 203 c# minor
# 204 C# major
# 205 c# minor
# 206 c# minor
# 207 c# minor
# 208 A- major
# 209 c# minor
# 210 A- major
# 211 c# minor
# 212 c# minor
# 213 f# minor
# 214 c# minor
# 215 c# minor
# 216 A- major
# 217 c# minor
# 218 A- major
# 219 C# major
# 220 C# major
# 221 c# minor
# 222 F# major
# 223 f# minor
# 224 f# minor
# 225 c# minor
# 226 c# minor
# 227 C major
# 228 F# major
# 229 D major
# 230 F major
# 231 c# minor
# 232 A- major
# 233 c# minor
# 234 c# minor
# 235 c# minor
# 236 A- major
# 237 c# minor
# 238 A- major
# 239 c# minor
# 240 f# minor
# 241 f# minor
# 242 f# minor
# 243 D major
# 244 D major
# 245 C major
# 246 C major
# 247 c# minor
# 248 c# minor
# 249 E major
# 250 C major
# 251 E major
# 252 c# minor
# 253 c# minor
# 254 c# minor
# 255 C major
# 256 C# major
# 257 c# minor
# 258 A- major
# 259 c# minor
# 260 A- major
# 261 C# major
# 262 C# major
# 263 c# minor
# 264 c# minor
# 265 c# minor
# 266 c# minor
# 267 c# minor

# %%
stream_left = midi_score.parts[1].flat.notesAndRests.stream()
stream_right = midi_score.parts[0].flat.notesAndRests.stream()

# %%
stream_left.show('midi')
stream_right.show('midi')
# Out:
#         <div id="midiPlayerDiv81764"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv81764_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv81764");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv81764_play, 2000);
#         } else {
#             midiPlayerDiv81764_play();
#         }
#         </script>
#         <div id="midiPlayerDiv102930"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv102930_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv102930");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv102930_play, 2000);
#         } else {
#             midiPlayerDiv102930_play();
#         }
#         </script>
